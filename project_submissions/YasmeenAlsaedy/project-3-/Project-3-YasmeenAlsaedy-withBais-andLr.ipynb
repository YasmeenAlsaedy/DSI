# %%
#import
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

pd.set_option('display.max_columns', 500)

# %%
# import data
train_data = pd.read_csv('../project-3-/train.csv')
test_data = pd.read_csv('../project-3-/test.csv')

# %%
# look at the train data
train_data.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
# ...

# %%
#look at the shape
train_data.shape
# Out:
# (2051, 82)

# %%
# look at the test data
test_data.head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0  Grvl       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 1   NaN       IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 2   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 3   NaN       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl        NAmes
#
# ...

# %%
#look at the shape
test_data.shape
# Out:
# (879, 80)

# %%
# look at the train data types
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 82 columns):
# Id                 2051 non-null int64
# PID                2051 non-null int64
# MS SubClass        2051 non-null int64
# MS Zoning          2051 non-null object
# Lot Frontage       1721 non-null float64
# Lot Area           2051 non-null int64
# Street             2051 non-null object
# Alley              140 non-null object
# Lot Shape          2051 non-null object
# Land Contour       2051 non-null object
# Utilities          2051 non-null object
# Lot Config         2051 non-null object
# Land Slope         2051 non-null object
# Neighborhood       2051 non-null object
# Condition 1        2051 non-null object
# Condition 2        2051 non-null object
# Bldg Type          2051 non-null object
# House Style        2051 non-null object
# Overall Qual       2051 non-null int64
# Overall Cond       2051 non-null int64
# Year Built         2051 non-null int64
# ...

# %%
# look at the test data types
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 80 columns):
# Id                 879 non-null int64
# PID                879 non-null int64
# MS SubClass        879 non-null int64
# MS Zoning          879 non-null object
# Lot Frontage       719 non-null float64
# Lot Area           879 non-null int64
# Street             879 non-null object
# Alley              58 non-null object
# Lot Shape          879 non-null object
# Land Contour       879 non-null object
# Utilities          879 non-null object
# Lot Config         879 non-null object
# Land Slope         879 non-null object
# Neighborhood       879 non-null object
# Condition 1        879 non-null object
# Condition 2        879 non-null object
# Bldg Type          879 non-null object
# House Style        879 non-null object
# Overall Qual       879 non-null int64
# Overall Cond       879 non-null int64
# Year Built         879 non-null int64
# ...

# %%
#get cloumns names 
clo_name_train = train_data.columns
clo_name_test =  test_data.columns

# %%
#convert the train data types to int
for _ in range(len(clo_name_train)):
    try:
        train_data[clo_name_train].astype('float64')
    except:
        continue 

#convert the test data types to int

for _ in range(len(clo_name_test)):
    try:
        test_data[clo_name_test].astype('float64')
    except:
        continue

# %%
# check the train_data info 
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 82 columns):
# Id                 2051 non-null int64
# PID                2051 non-null int64
# MS SubClass        2051 non-null int64
# MS Zoning          2051 non-null object
# Lot Frontage       1721 non-null float64
# Lot Area           2051 non-null int64
# Street             2051 non-null object
# Alley              140 non-null object
# Lot Shape          2051 non-null object
# Land Contour       2051 non-null object
# Utilities          2051 non-null object
# Lot Config         2051 non-null object
# Land Slope         2051 non-null object
# Neighborhood       2051 non-null object
# Condition 1        2051 non-null object
# Condition 2        2051 non-null object
# Bldg Type          2051 non-null object
# House Style        2051 non-null object
# Overall Qual       2051 non-null int64
# Overall Cond       2051 non-null int64
# Year Built         2051 non-null int64
# ...

# %%
# check the test_data info 
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 82 columns):
# Id                 2051 non-null int64
# PID                2051 non-null int64
# MS SubClass        2051 non-null int64
# MS Zoning          2051 non-null object
# Lot Frontage       1721 non-null float64
# Lot Area           2051 non-null int64
# Street             2051 non-null object
# Alley              140 non-null object
# Lot Shape          2051 non-null object
# Land Contour       2051 non-null object
# Utilities          2051 non-null object
# Lot Config         2051 non-null object
# Land Slope         2051 non-null object
# Neighborhood       2051 non-null object
# Condition 1        2051 non-null object
# Condition 2        2051 non-null object
# Bldg Type          2051 non-null object
# House Style        2051 non-null object
# Overall Qual       2051 non-null int64
# Overall Cond       2051 non-null int64
# Year Built         2051 non-null int64
# ...

# %%
#rename the cloums 
train_data_columns = [name.replace(' ', '_') if ' ' in name else name for name in clo_name_train ]
test_data_columns = [name.replace(' ', '_') if ' ' in name else name for name in clo_name_test ]

# %%
train_data.columns = train_data_columns
test_data.columns = test_data_columns

# %%
#check the train dataframe names
train_data.head()
# Out:
#     Id        PID  MS_SubClass MS_Zoning  Lot_Frontage  Lot_Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot_Shape Land_Contour Utilities Lot_Config Land_Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
# ...

# %%
#check the test dataframe names
test_data.head()
# Out:
#      Id        PID  MS_SubClass MS_Zoning  Lot_Frontage  Lot_Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot_Shape Land_Contour Utilities Lot_Config Land_Slope Neighborhood  \
# 0  Grvl       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 1   NaN       IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 2   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 3   NaN       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl        NAmes
#
# ...

# %%
# check train data the nulls
print('null values in train', train_data.isnull().sum().sum())
print('null values in test', test_data.isnull().sum().sum())
# Out:
# null values in train 9822
# null values in test 4175

# %%
#fill all null
train_data['Pool_QC'].fillna('No Pool', inplace=True) 
train_data['Misc_Feature'].fillna('Na', inplace=True) 
train_data['Alley'].fillna('No alley access', inplace=True) 
train_data['Fence'].fillna('No Fence', inplace=True) 
train_data['Fireplaces'].fillna('No Fireplace', inplace=True) 
train_data['Garage_Cond'].fillna('No Garage cond', inplace=True) 
train_data['Garage_Qual'].fillna('No Garage qual', inplace=True)

#fill all null
test_data['Pool_QC'].fillna('No Pool', inplace=True) 
test_data['Misc_Feature'].fillna('Na', inplace=True) 
test_data['Alley'].fillna('No alley access', inplace=True) 
test_data['Fence'].fillna('No Fence', inplace=True) 
test_data['Fireplaces'].fillna('No Fireplace', inplace=True) 
test_data['Garage_Cond'].fillna('No Garage cond', inplace=True) 
test_data['Garage_Qual'].fillna('No Garage qual', inplace=True)

# %%
# #fill all null with 0
train_data.fillna(0, inplace=True)
test_data.fillna(0, inplace=True)

# %%
#check the null value
print('null values in train', train_data.isnull().sum().sum())
print('null values in test', test_data.isnull().sum().sum())
# Out:
# null values in train 0
# null values in test 0

# %%
# train data describe
train_data.describe()
# Out:
#                 Id           PID  MS_SubClass  Lot_Frontage       Lot_Area  \
# count  2051.000000  2.051000e+03  2051.000000   2051.000000    2051.000000
# mean   1474.033642  7.135900e+08    57.008776     57.944417   10065.208191
# std     843.980841  1.886918e+08    42.824223     33.137332    6742.488909
# min       1.000000  5.263011e+08    20.000000      0.000000    1300.000000
# 25%     753.500000  5.284581e+08    20.000000     43.500000    7500.000000
# 50%    1486.000000  5.354532e+08    50.000000     63.000000    9430.000000
# 75%    2198.000000  9.071801e+08    70.000000     78.000000   11513.500000
# max    2930.000000  9.241520e+08   190.000000    313.000000  159000.000000
#
#        Overall_Qual  Overall_Cond   Year_Built  Year_Remod/Add  Mas_Vnr_Area  \
# count   2051.000000   2051.000000  2051.000000     2051.000000   2051.000000
# mean       6.112140      5.562165  1971.708922     1984.190151     98.626524
# ...

# %%
#The outliers in train data
sns.regplot(train_data.Gr_Liv_Area, train_data.SalePrice);

# %%
# drop the data that more than 50000
outliers = train_data[train_data.Gr_Liv_Area > 5000]
outliers
# Out:
#         Id        PID  MS_SubClass MS_Zoning  Lot_Frontage  Lot_Area Street  \
# 960   1499  908154235           60        RL         313.0     63887   Pave
# 1885  2181  908154195           20        RL         128.0     39290   Pave
#
#                 Alley Lot_Shape Land_Contour Utilities Lot_Config Land_Slope  \
# 960   No alley access       IR3          Bnk    AllPub     Corner        Gtl
# 1885  No alley access       IR1          Bnk    AllPub     Inside        Gtl
#
#      Neighborhood Condition_1 Condition_2 Bldg_Type House_Style  Overall_Qual  \
# 960       Edwards       Feedr        Norm      1Fam      2Story            10
# 1885      Edwards        Norm        Norm      1Fam      1Story            10
#
#       Overall_Cond  Year_Built  Year_Remod/Add Roof_Style Roof_Matl  \
# 960              5        2008            2008        Hip   ClyTile
# 1885             5        2008            2009        Hip   CompShg
#
# ...

# %%
#drop the outliers
train_data.drop(outliers.index, inplace=True,  axis=0)

# %%
# after delete the outliers
sns.regplot(train_data.Gr_Liv_Area, train_data.SalePrice);

# %%
#after remove the 2 outliers
train_data.shape
# Out:
# (2049, 82)

# %%
#see the outliers from SalePrice cloumns
train_data.SalePrice.hist( color="r", alpha=0.5, bins=50,figsize=(20,30));

# %%
# remove all the data that are greater that 2 std from the main
train_without_outliers = train_data[(train_data.SalePrice-train_data.SalePrice.mean()) < (2*train_data.SalePrice.std())]
train_without_outliers.SalePrice.hist( color="r", alpha=0.5, bins=50,figsize=(20,30));

# %%
# after drop the outliers
train_without_outliers.shape
# Out:
# (1955, 82)

# %% [markdown]
# ## Preprocessing

# %%
#drop the Sales
sale_condeition = train_without_outliers.pop('Sale_Condition')
Sales_price =  train_without_outliers.pop('SalePrice')

# %%
data = pd.concat([train_without_outliers, test_data], sort=False)

# %%
# create dummies values 
data_dummies = pd.get_dummies(data, drop_first=True)

# %%
train_data_dummies = data_dummies[: len(train_without_outliers)]
test_data_dummies = data_dummies[len(train_without_outliers): ]

# %%
# see the shape of the train_data and test_data after dummies
print('train_data_dummies', train_data_dummies.shape)
print('test_data_dummies', test_data_dummies.shape)
# Out:
# train_data_dummies (1955, 272)
# test_data_dummies (879, 272)

# %%
# encode the Sale_Condition
EncodedSaleConditionDictionary = {'Abnorml': 1, 'Normal': 0, 'Partial': 0, 'Family' : 0, 'Alloca' : 0, 'AdjLand' : 0}
train_data_dummies['Encoded_Sale_Condition'] = sale_condeition.map(EncodedSaleConditionDictionary)
# Out:
# /Users/jasmine/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# look at the Endoded Sale condition
train_data_dummies['Encoded_Sale_Condition'].head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Encoded_Sale_Condition, dtype: int64

# %%
#withOnes = train_data_dummies[ train_data_dummies.Encoded_Sale_Condition > 0 ]

# %%
# withOnes.Encoded_Sale_Condition.sum()

# %%
# withZeroes = train_data_dummies[ train_data_dummies.Encoded_Sale_Condition < 1 ].iloc[:130 , :]

# %%
# DatawithNowBais = pd.concat([withZeroes, withOnes], sort=False)

# %%
#list(train_data_dummies.columns)

# %% [markdown]
# ## Sperate the data

# %%
# outside_house= train_data_dummies.loc[:, ['MS_SubClass','MS_Zoning_C (all)', 'MS_Zoning_FV',
#                                           'MS_Zoning_I (all)', 'MS_Zoning_RH', 'MS_Zoning_RL',
#                                           'MS_Zoning_RM','Lot_Frontage','Street_Pave','Alley_No alley access',
#               'Alley_Pave', 'Land_Contour_Low','Land_Contour_HLS', 'Land_Contour_Lvl'
#        'Lot_Config', 'Land_Slope', 'Neighborhood', 'Condition_1',
#        'Condition_2','Encoded_Sale_Condition']]

# %%
# correlation 
corr_Sale_Condition = np.abs(train_data_dummies.corr()['Encoded_Sale_Condition']).sort_values(ascending=False)[:11]
corr_Sale_Condition
# Out:
# Encoded_Sale_Condition    1.000000
# MS_Zoning_C (all)         0.161906
# Year_Remod/Add            0.145635
# Overall_Qual              0.144368
# Central_Air_Y             0.139869
# Year_Built                0.129551
# Sale_Type_WD              0.128236
# Neighborhood_IDOTRR       0.126970
# Foundation_PConc          0.126945
# Garage_Cond_TA            0.125680
# Garage_Cars               0.124406
# Name: Encoded_Sale_Condition, dtype: float64

# %%
# init X, y
y = train_data_dummies.pop('Encoded_Sale_Condition')
X = train_data_dummies

# %%
# Call the train_test_split
from sklearn.model_selection import train_test_split, GridSearchCV, 
cross_val_score, cross_val_predict

# %%
# To validate the model
X_train, X_validate, y_train, y_validate = train_test_split(X, y,
                                                            random_state=42, stratify=y)

# %%
# import Scale
from sklearn.preprocessing import StandardScaler

# %%
# #Scale the data
ss = StandardScaler()
ss.fit(X)
X_train_scaled = ss.transform(X)
X_validate_scaled = ss.transform(X_validate)

# %% [markdown]
# ## Start modeling

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, cohen_kappa_score, make_scorer

# %%
#import 
from sklearn.neighbors import KNeighborsClassifier

# %%
cohen_score = make_scorer(cohen_kappa_score)

# %%
# init the model
knn = KNeighborsClassifier()

# %%
#First do the gride search
params = {
    'n_neighbors': range(1,30),
    'weights': ['uniform', 'distance'],
    'p': [1,2]
}
gs = GridSearchCV(knn, params)

# %%
# fit the model 
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform'),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'n_neighbors': range(1, 30), 'weights': ['uniform', 'distance'], 'p': [1, 2]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
#import
from sklearn.metrics import mean_squared_error

# %%
# socre on the validation data
gs.score(X_validate, y_validate)
# Out:
# 0.9325153374233128

# %%
#look at the cross validation socre
print('Mean cross validation socre for training', cross_val_score(knn, X_train, y_train, cv=5).mean())
# Out:
# Mean cross validation socre for training 0.930423881179944

# %%
#predict the value
y_pred = cross_val_predict(gs, X_train, y_train , cv=5)

# %%
y_pred[:len(test_data_dummies)].sum()
# Out:
# 1

# %%
test_data['SaleCondition'] = y_pred[:len(test_data_dummies)]

# %%
test_data['SaleCondition'].sum()
# Out:
# 1

# %%
test_data[['Id', 'SaleCondition']].to_csv('model_submissionClassification3.csv', index = False)

# %%
#import 
from sklearn import metrics

# %%
#Score the model
knn_score = metrics.accuracy_score(y_train[:879], y_pred[:len(test_data_dummies)])
print('accuracy score', knn_score)
# Out:
# accuracy score 0.9328782707622298

# %%
test_data['Sale_Condition'] = y_pred
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-812f031110e8> in <module>()
# ----> 1 test_data['Sale_Condition'] = y_pred
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3114         else:
#    3115             # set column
# -> 3116             self._set_item(key, value)
#    3117
#    3118     def _setitem_slice(self, key, value):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3189
#    3190         self._ensure_valid_index(value)
# -> 3191         value = self._sanitize_column(key, value)
#    3192         NDFrame._set_item(self, key, value)
#    3193
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3386
#    3387             # turn me into an ndarray
# ...

# %%
y_pred.sum()

# %%
test_data[['Id', 'Sale_Condition']].head()

# %%
to_csv(

# %%
# import desicion tree
from sklearn.tree import DecisionTreeClassifier

# %%
# init the model
clf = DecisionTreeClassifier()

# %%
# fit the model
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
#score 
clf.score(X_validate_scaled, y_validate)
# Out:
# 0.9325153374233128

# %%
#predict from the 
y_pred_tree = clf.predict(test_data_dummies)

# %%
#Score the model
dt_score = metrics.accuracy_score(y_train[:879], y_pred_tree)
print('accuracy score', dt_score)
# Out:
# accuracy score 0.8816837315130831

# %%
#look at the cross validation socre
print('Mean cross validation socre for training', cross_val_score(clf, X_train, y_train, cv=5).mean())
# Out:
# Mean cross validation socre for training 0.8799512464764296

# %%
y_pred_tree.sum()
# Out:
# 58

# %%
metrics.f1_score(y_train[:879], y_pred_tree)
# Out:
# 0.10344827586206896

# %%
test_data.SaleCondition = y_pred_tree

# %%
test_data[['Id', 'SaleCondition']].to_csv('model_submissionClassificationwith58Ones.csv', index = False)

# %%
#Bagging
from sklearn.ensemble import BaggingClassifier

param_grid = {
    'base_estimator__max_depth' : [1, 2, 3, 4, 5],
    'max_samples' : [0.05, 0.1, 0.2, 0.5]
}

bclf = GridSearchCV(BaggingClassifier(DecisionTreeClassifier(),
                                     n_estimators = 100, max_features = 0.5), param_grid)
bclf.fit(X_train, y_train)
bclf.score(X_validate_scaled, y_validate)

#predict from the 
y_pred_bclf = bclf.predict(test_data_dummies)
bclf_score = metrics.accuracy_score(y_train[:879], y_pred_bclf)
print('accuracy score', bclf_score)

# %%
#logistic regration 
from sklearn.linear_model import LogisticRegressionCV

# %%
lr = LogisticRegressionCV(scoring=cohen_score)
lr.fit(X_train, y_train)
lr.score(X_validate_scaled, y_validate)

# %%
y_pred_lr = lr.predict(test_data_dummies)
lr_score = metrics.accuracy_score(y_train[:879], y_pred_lr)
print('accuracy score', lr_score)

# %%
#visualize the score
data = [['knn', knn_score], ['Decision tree', dt_score], ['Bagging Clf', bclf_score],
       ['Logistic Regression', lr_score]]
visualize_df = pd.DataFrame(data=data , columns=['model', 'score'])
plt.bar(visualize_df['model'], visualize_df['score'] )
