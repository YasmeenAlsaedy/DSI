# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Practice Using APIs
#
# _Instructor: Aymeric Flaisler_
#
# ---
#
# In this lab we will practice using some popular APIs to retrieve and store data.

# %%
# Imports at the top
import json
import urllib
import pandas as pd
import numpy as np
import requests
import json
import re
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup


# %matplotlib inline

# %% [markdown]
# ## Exercise 1: get data from Sheetsu
#
# ---
#
# [Sheetsu](https://sheetsu.com/) is an online service that allows you to access any Google spreadsheet from an API. This can be a very powerful way to share a dataset with colleagues as well as to create a mini centralized data storage that is simpler to edit than a database.
#
# A Google Spreadsheet with Wine data can be found [here](https://docs.google.com/spreadsheets/d/1mZ3Otr5AV4v8WwvLOAvWf3VLxDa-IeJ1AVTEuavJqeo/).
#
# It can be accessed through sheetsu API at this endpoint: https://sheetsu.com/apis/v1.0/2899e32f4844
#
# **Questions:**
#
# 1. Use the requests library to access the document. Inspect the response text. What kind of data is it?
# - Check the status code of the response object. What code is it?
# - Use the appropriate libraries and read functions to read the response into a Pandas Dataframe.
# - Once you've imported the data into a dataframe, check the value of the 5th line: what's the price?

# %%
#import the sheetsu to read the google sheet 
from sheetsu import SheetsuClient

# %%
# You can either post or get info from this API
api_base_url = 'https://sheetsu.com/apis/v1.0su/4ce9c3459aad'

# %%
# A:
#get the sheet data
client = SheetsuClient("https://sheetsu.com/apis/v1.0ly/020b2c0f")

# %%
#showing the data 
client.read()
# Out:
# [{'id': '1',
#   'name': 'Peter',
#   'score': '42',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '2',
#   'name': 'Lois',
#   'score': '89',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '3',
#   'name': 'Meg',
#   'score': '10',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '4',
#   'name': 'Chris',
#   'score': '42',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'jart',
#   'score': '123123',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '6999',
#   'name': 'GlennOscar',
#   'score': '69000',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'tes',
#   'score': 'asdf',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'tes',
#   'score': 'asdf',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'dfadf',
#   'score': 'asdfd',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'dfadf',
#   'score': 'asdfd',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Recipiente',
#   'score': '20',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Recipiente',
#   'score': '20',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Recipiente',
#   'score': '20',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Recipiente',
#   'score': '20',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Sello',
#   'score': '80',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'yo bitch',
#   'score': 'hello',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'hello',
#   'score': 'test',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Thảo ',
#   'score': '10',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Hoàng Xuân Quân',
#   'score': '100',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Hoàng Xuân Quân',
#   'score': '100',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Hoàng Xuân Quân',
#   'score': '100',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Hoàng Xuân Bảo Nam',
#   'score': '1000',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'HỌ Và Tên',
#   'score': '100000',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'HỌ Và Tên',
#   'score': '100000',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Ee',
#   'score': 'Des',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Ee',
#   'score': 'Des',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Ee',
#   'score': 'Des',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Ee',
#   'score': 'Des',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Ee',
#   'score': 'Des',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Test',
#   'score': 'Test',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Test',
#   'score': 'Test',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Aaaa',
#   'score': '99999999',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': '3213',
#   'score': '123123',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'a',
#   'score': 's',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Hoàng Xuân Quân',
#   'score': '',
#   'phone': '912665660',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Hoàng Xuân Bảo Nam',
#   'score': '',
#   'phone': '912665660',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Nguyễn Văn A',
#   'score': '',
#   'phone': '912345678',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Nguyễn văn A',
#   'score': '',
#   'phone': '966316056',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'test',
#   'score': 'test',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': '',
#   'score': '',
#   'phone': '',
#   'first_name': 'test',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': '',
#   'score': '',
#   'phone': '',
#   'first_name': 'test',
#   'last_name': 'test',
#   'email': 'test@gmailc.om',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': '',
#   'score': '',
#   'phone': '',
#   'first_name': 'sam',
#   'last_name': 'harvey',
#   'email': 'sam@gmail.com',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': '',
#   'score': '',
#   'phone': '',
#   'first_name': 'test',
#   'last_name': 'test',
#   'email': 'test@gmail.com',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': '',
#   'score': '',
#   'phone': '',
#   'first_name': 'Sam',
#   'last_name': 'Harvey',
#   'email': 'test@gmail.com',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': '',
#   'score': '',
#   'phone': '',
#   'first_name': 'Sam',
#   'last_name': 'Harvey',
#   'email': 'test@gmail.com',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': '',
#   'score': '',
#   'phone': '',
#   'first_name': 'sam',
#   'last_name': 'harvey',
#   'email': 'test@gmail.com',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '5',
#   'name': 'John',
#   'score': '200',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '5',
#   'name': 'John',
#   'score': '200',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '5',
#   'name': 'John',
#   'score': '200',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '5',
#   'name': 'John',
#   'score': '200',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '2',
#   'name': 'John',
#   'score': '400',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '5',
#   'name': 'John',
#   'score': '200',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '2',
#   'name': 'John',
#   'score': '400',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Ryr',
#   'score': 'Yeye',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Quan Hoang',
#   'score': '',
#   'phone': '912665660',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': 'Hà Nội',
#   'gender': 'Nam',
#   'address': 'Ha Noi',
#   'datetime': '06/12/2018, 8:44:40 pm',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'Hoàng Xuân Bảo Nam',
#   'score': '',
#   'phone': '912665660',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '5',
#   'name': 'John',
#   'score': '200',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'den',
#   'score': '100500',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'aSa',
#   'score': 'asa',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'aSa',
#   'score': 'asa',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'PEDRO',
#   'score': 'GABRIELK',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': 'PEDRO',
#   'score': 'GABRIELK',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': '',
#   'Phone Number': ''},
#  {'id': '',
#   'name': '',
#   'score': '',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': 'Harsh',
#   'Phone Number': ''},
#  {'id': '',
#   'name': '',
#   'score': '',
#   'phone': '',
#   'first_name': '',
#   'last_name': '',
#   'email': '',
#   'city': '',
#   'gender': '',
#   'address': '',
#   'datetime': '',
#   'Name': 'Harsh',
#   'Phone Number': '9773848099'}]

# %%
google_sheet = []

#get the data and append it in the google_sheet list
for row in client.read():
    google_sheet.append([row['id'], row['name']
                         , row['score'], row['phone'], row['first_name'], row['last_name']
                        , row['email'], row['city'], row['gender'], row['address']
                        , row['datetime'], row['Name'], row['Phone Number']])

# %%
#create dataframe
df = pd.DataFrame(google_sheet, columns=['id', 'name', 'score', 'phone', 'first_name'
                                        ,'last_name', 'email', 'city', 'gender', 'address',
                                       'datetime','Name','Phone_Number'])

# %%
#showing the df data
df.head()
# Out:
#   id   name   score phone first_name last_name email city gender address  \
# 0  1  Peter      42
# 1  2   Lois      89
# 2  3    Meg      10
# 3  4  Chris      42
# 4      jart  123123
#
#   datetime Name Phone_Number
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Exercise 2: post data to Sheetsu
#
# ---
#
# We've learned how to read data, but it'd be great if we could also write data. For this we will need to use a _POST_ request.
#
# 1. Use the post command to add the `post_data` to the spreadsheet.
# - What status did you get? How can you check that you actually added the data correctly?
# - In this exercise, your classmates are adding data to the same spreadsheet. What happens because of this? Is it a problem? How could you mitigate it?

# %%
post_data = {
'Grape' : ''
, 'Name' : 'My wonderful wine'
, 'Color' : 'R'
, 'Country' : 'US'
, 'Region' : 'Sonoma'
, 'Vinyard' : ''
, 'Score' : '10'
, 'Consumed In' : '2015'
, 'Vintage' : '1973'
, 'Price' : '200'
}

# %%
# A:

# %% [markdown]
# ## Exercise 3: IMDB TV Shows
#
# ---
#
# Sometimes an API doesn't provide all the information we would like to get and we need to be creative.
#
# Here we will use a combination of scraping and API calls to find the ratings and networks of famous television shows.

# %% [markdown]
# ### 3.A Get the top TV Shows
#
# The Internet Movie Database contains data about movies and TV shows. Unfortunately it does not have a public API.
#
# The page http://www.imdb.com/chart/toptv/?ref_=nv_tp_tv250_2 contains the list of the top 250 tv shows of all time. Retrieve the page using the requests library and then parse the html to obtain a list of the `movie_ids` for these movies. You can parse it with regular expression or using a library like `BeautifulSoup`.
#
# > **Hint:** movie_ids look like this: `tt2582802`
# > _Everything after "/title/" and before "/?"_

# %%
# A:
#set the url
url = 'http://www.imdb.com/chart/toptv/?ref_=nv_tp_tv250_2'

#get the text from the url
html = requests.get(url)

html.text
# Out:
# '\n\n\n<!DOCTYPE html>\n<html\n    xmlns:og="http://ogp.me/ns#"\n    xmlns:fb="http://www.facebook.com/2008/fbml">\n    <head>\n         \n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    \n    \n    \n\n    \n    \n    \n\n    <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///?src=mdot">\n            <style>\n                body#styleguide-v2 {\n                    background: no-repeat fixed center top #000;\n                }\n            </style>\n\n\n\n        <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:\'java\'};</script>\n\n<script>\n    if (typeof uet == \'function\') {\n      uet("bb", "LoadTitle", {wb: 1});\n    }\n</script>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>\n        <title>IMDb Top 250 TV - IMDb</title>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>\n<script>\n    if (typeof uet == \'function\') {\n      uet("be", "LoadTitle", {wb: 1});\n    }\n</script>\n<script>\n    if (typeof uex == \'function\') {\n      uex("ld", "LoadTitle", {wb: 1});\n    }\n</script>\n\n        <link rel="canonical" href="https://www.imdb.com/chart/toptv/" />\n        <meta property="og:url" content="http://www.imdb.com/chart/toptv/" />\n\n<script>\n    if (typeof uet == \'function\') {\n      uet("bb", "LoadIcons", {wb: 1});\n    }\n</script>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_icon"] = new Date().getTime(); })(IMDbTimer);</script>\n        <link href="https://m.media-amazon.com/images/G/01/imdb/images/safari-favicon-517611381._CB483525257_.svg" mask rel="icon" sizes="any">\n        <link rel="icon" type="image/ico" href="https://m.media-amazon.com/images/G/01/imdb/images/favicon-2165806970._CB470047330_.ico" />\n        <meta name="theme-color" content="#000000" />\n        <link rel="shortcut icon" type="image/x-icon" href="https://m.media-amazon.com/images/G/01/imdb/images/desktop-favicon-2165806970._CB484110913_.ico" />\n        <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-4151659188._CB483525313_.png" rel="apple-touch-icon"> \n        <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-76x76-53536248._CB484146059_.png" rel="apple-touch-icon" sizes="76x76"> \n        <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-120x120-2442878471._CB483525250_.png" rel="apple-touch-icon" sizes="120x120"> \n        <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-152x152-1475823641._CB470042035_.png" rel="apple-touch-icon" sizes="152x152">            \n        <link rel="search" type="application/opensearchdescription+xml" href="https://m.media-amazon.com/images/G/01/imdb/images/imdbsearch-3349468880._CB470047351_.xml" title="IMDb" />\n  <script>(function(t){ (t.events = t.events || {})["csm_head_post_icon"] = new Date().getTime(); })(IMDbTimer);</script>\n<script>\n    if (typeof uet == \'function\') {\n      uet("be", "LoadIcons", {wb: 1});\n    }\n</script>\n<script>\n    if (typeof uex == \'function\') {\n      uex("ld", "LoadIcons", {wb: 1});\n    }\n</script>\n\n\n\n            <title>IMDb Top Rated TV Shows</title>\n<meta name="description" content="Check out the top 250 TV shows as rated by IMDb users"/>\n<meta name="robots" content="index,follow"/>\n<meta itemprop="description" content="Check out the top 250 TV shows as rated by IMDb users"/>\n<meta itemprop="image" content="https://m.media-amazon.com/images/M/MV5BZWYxODViMGYtMGE2ZC00ZGQ3LThhMWUtYTVkNGE3OWU4NWRkL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjYwNDA2MDE@._V1_SY1000_CR0,0,666,1000_AL_.jpg"/>\n<meta itemprop="name" content="IMDb Top Rated TV Shows"/>\n<meta property="pageType" content="chart"/>\n<meta property="subpa ...

# %%
#get all the movies id then get all the unique ids
movie_list = list(set(re.findall('<a href="/title/(.*?)/', html.text)))

# %%
len(movie_list)
# Out:
# 251

# %% [markdown]
# ### 3.B Get data on the top movies
#
# Although the Internet Movie Database does not have a public API, an open API exists at http://www.tvmaze.com/api.
#
# Use this API to retrieve information about each of the 250 TV shows you have extracted in the previous step.
# 1. Check the documentation of tvmaze's api to learn how to request show data by id.
# - Define a function that returns a python object with select information for a given id.
#     - Show name
#     - Rating (avg)
#     - Genre(s)
#     - Network name
#     - Premiere date
#     - Status
# > Tip: the json object can easily be converted into a python dictionary.
#
# - Store the gathered information in a Pandas Dataframe.
#
# As the target information is in json format you will need `json.loads()` in order to gather it.

# %%
# A:
#set the requset link 
tv_show_links = requests.get('http://api.tvmaze.com/lookup/shows?imdb=tt1526318')

#load the data as json file
json.loads(tv_show_links.text)
# Out:
# {'id': 3934,
#  'url': 'http://www.tvmaze.com/shows/3934/borgen',
#  'name': 'Borgen',
#  'type': 'Scripted',
#  'language': 'Danish',
#  'genres': ['Drama'],
#  'status': 'Ended',
#  'runtime': 60,
#  'premiered': '2010-09-26',
#  'officialSite': None,
#  'schedule': {'time': '20:00', 'days': ['Sunday']},
#  'rating': {'average': 8.2},
#  'weight': 66,
#  'network': {'id': 115,
#   'name': 'DR1',
#   'country': {'name': 'Denmark',
#    'code': 'DK',
#    'timezone': 'Europe/Copenhagen'}},
#  'webChannel': None,
#  'externals': {'tvrage': 26716, 'thetvdb': 193261, 'imdb': 'tt1526318'},
#  'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/19/48992.jpg',
#   'original': 'http://static.tvmaze.com/uploads/images/original_untouched/19/48992.jpg'},
#  'summary': '<p>Internationally acclaimed Danish political drama from the producers of The Killing.</p>',
#  'updated': 1541673499,
#  '_links': {'self': {'href': 'http://api.tvmaze.com/shows/3934'},
#   'previousepisode': {'href': 'http://api.tvmaze.com/episodes/252664'}}}

# %%
#create the df
df_tv_shows = pd.DataFrame(columns = ['name', 'rating_average', 'genres', 'network', 'premier', 'status'])

# %%
#create function to get all the TV show data 
def tv_shows(movieid):
    tv_show_link = requests.get('http://api.tvmaze.com/lookup/shows?imdb=' + movieid)
    
    #if the code is (200 == ok) get the data
    if tv_show_link.status_code == 200: 
        #try and except if the data is null we can't load it so we set it as null
        #in the dataframe
        try:
            name = json.loads(tv_show_link.text).get('name')
        except AttributeError:
            name = np.nan

        try:
            rating = json.loads(tv_show_link.text).get('rating').get('average')
        except AttributeError:
            rating = np.nan

        try:
            genres = json.loads(tv_show_link.text).get('genres')
        except AttributeError:
            genres = np.nan

        try:
            network = json.loads(tv_show_link.text).get('network').get('name')
        except AttributeError:
            network = np.nan

        try:
            premier = json.loads(tv_show_link.text).get('premiered')
        except AttributeError:
            premier = np.nan

        try:
            status = json.loads(tv_show_link.text).get('status')
        except AttributeError:
            status = np.nan

        return [name, rating, genres, network, premier, status]

# %%
#fill the df with movie data
for movieid in movie_list:
    df_tv_shows.loc[len(df_tv_shows)] = tv_shows(movieid)

# %%
df_tv_shows.head()
# Out:
#                name rating_average                    genres         network  \
# 0              Feud            7.4                   [Drama]              FX
# 1         Entourage            7.9           [Drama, Comedy]             HBO
# 2          Şahsiyet           None  [Drama, Crime, Thriller]             NaN
# 3  Chappelle's Show              8                  [Comedy]  Comedy Central
# 4      The Night Of            8.6     [Drama, Crime, Legal]             HBO
#
#       premier            status
# 0  2017-03-05  To Be Determined
# 1  2004-07-18             Ended
# 2  2018-03-17             Ended
# 3  2003-01-22             Ended
# 4  2016-07-10             Ended
