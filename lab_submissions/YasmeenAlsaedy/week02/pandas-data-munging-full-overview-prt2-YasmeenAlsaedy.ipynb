# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # `pandas` Data Munging Overview: Part 2
#
#
# ---

# %% [markdown]
# ### Lesson Guide
# - [Exercise #3](#exercise-3)
# - [Split-Apply-Combine](#split-apply-combine)
#     - [`.groupby()`](#groupby)
#     - [Apply Functions to Groups and Combine](#apply-combine)
# - [Exercise #4](#exercise-4)
# - [Indexing](#indexing)
#     - [Location Indexing With `.loc()`](#loc)
#     - [Position Indexing With `.iloc()`](#iloc)
# - [Other Frequently Used Features](#frequent)
#     - [Using Map Functions With Replacement Dictionaries](#map-dict)
#     - [Encoding Strings as Integers With `.factorize()`](#factorize)
#     - [Determining Unique Values](#unique)
#     - [Replacing Values With `.replace()`](#replace)
#     - [Series String Methods With `.str`](#series-str)
#     - [Datetime Conversion and Arithmetic](#datetime)
#     - [Setting and Resetting the Index](#set-reset-index)
#     - [Sorting by Index](#sort-by-index)
#     - [Changing the Data Type of a Column](#change-dtype)
#     - [Creating Dummy-Coded Columns](#dummy)
#     - [Concatenating DataFrames](#concatenate)
#     - [Detecting and Dropping Duplicate Rows](#duplicate-rows)
#     - [Writing a DataFrame to a `.csv`](#write-csv)
#     - [Pickling a DataFrame](#pickle)
#     - [Randomly Sampling a DataFrame](#sample)
# - [Infrequently Used Features](#infrequent)
#     - [Creating DataFrames From Dictionaries and Lists of Lists](#toy-dataframes)
#     - [Performing Cross-Tabulations](#crosstab)
#     - [Query-Filtering Syntax](#query)
#     - [Calculating Memory Usage](#memory-usage)
#     - [Converting Column to Category Type](#category-type)
#     - [Creating Columns With `.assign()`](#assign)
#     - [Limiting the Number of Rows to Load in a File Read](#limit-rows-read)
#     - [Manually Setting the Number of Rows and Columns to Print](#manual-print)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <a id='exercise-3'></a>
# ## Exercise #3
#
# ---
#
# **Using the UFO data provided below:**
# 1. Read in the data.
# 2. Check the shape and describe the columns.
# 3. Find the four most frequently reported colors.
# 4. Find the most frequent city for reports in state `VA`.
# 5. Find only UFO reports from Arlington, VA.
# 6. Find the number of missing values in each column.
# 7. Show only UFO reports where `city` is missing.
# 8. Count the number of rows with no null values.
# 9. Amend column names with spaces to have underscores.
# 10. Make a new column that is a combination of `city` and `state`.

# %%
ufo_csv = '../../../../resource-datasets/ufo_sightings/ufo.csv'

# %%
# A:
ufo = pd.read_csv(ufo_csv)

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# <a id='split-apply-combine'></a>
# ## Split-Apply-Combine
#
# ---
#
# ![](assets/split_apply_combine.png)

# %% [markdown]
# <a id='groupby'></a>
# ### `.groupby()`
#
# **Q.1** Using the `drinks` DataFrame, calculate the mean `beer` servings by continent.

# %%
drinks = pd.read_csv('../../../../resource-datasets/alcohol_by_country/drinks.csv')
column_names = ['country', 'beer', 'spirit', 'wine', 'liters', 'continent']
drinks.columns = column_names

# %%
# A:
drinks['beer'].mean()
# Out:
# 106.16062176165804

# %%
drinks.head()
# Out:
#        country  beer  spirit  wine  liters continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU
# 2      Algeria    25       0    14     0.7        AF
# 3      Andorra   245     138   312    12.4        EU
# 4       Angola   217      57    45     5.9        AF

# %% [markdown]
# **Q.2** Describe the `beer` column by continent.

# %%
# A:
groupbyContinent = drinks.groupby('continent')
groupbyContinent['beer'].describe()
# Out:
#            count        mean        std   min     25%    50%     75%    max
# continent
# AF          53.0   61.471698  80.557816   0.0   15.00   32.0   76.00  376.0
# AS          44.0   37.045455  49.469725   0.0    4.25   17.5   60.50  247.0
# EU          45.0  193.777778  99.631569   0.0  127.00  219.0  270.00  361.0
# OC          16.0   89.687500  96.641412   0.0   21.00   52.5  125.75  306.0
# SA          12.0  175.083333  65.242845  93.0  129.50  162.5  198.00  333.0

# %% [markdown]
# <a id='apply-combine'></a>
# ### Apply Functions to Groups and Combine
#
# **Q.1** Find the `count`, `mean`, `minimum`, and `maximum `of the `beer` column by continent.

# %%
# A:
print('mean :' , groupbyContinent['beer'].mean())
print('count :' , groupbyContinent['beer'].count())
print('min :' ,groupbyContinent['beer'].min())
print('mx :' ,groupbyContinent['beer'].max())
# Out:
# mean : continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer, dtype: float64
# count : continent
# AF    53
# AS    44
# EU    45
# OC    16
# SA    12
# Name: beer, dtype: int64
# min : continent
# AF     0
# AS     0
# EU     0
# OC     0
# SA    93
# Name: beer, dtype: int64
# mx : continent
# AF    376
# AS    247
# EU    361
# OC    306
# SA    333
# Name: beer, dtype: int64

# %% [markdown]
# **Q.2** Perform the same task as in Q.1, but now sort the output by the `mean` column.

# %%
# A:
groupbyContinent = drinks.groupby('continent' , sort=False)
groupbyContinent.beer.describe().sort_values('mean' , ascending=False)
# Out:
#            count        mean        std   min     25%    50%     75%    max
# continent
# EU          45.0  193.777778  99.631569   0.0  127.00  219.0  270.00  361.0
# SA          12.0  175.083333  65.242845  93.0  129.50  162.5  198.00  333.0
# OC          16.0   89.687500  96.641412   0.0   21.00   52.5  125.75  306.0
# AF          53.0   61.471698  80.557816   0.0   15.00   32.0   76.00  376.0
# AS          44.0   37.045455  49.469725   0.0    4.25   17.5   60.50  247.0

# %% [markdown]
# **Q.3** Apply a custom function to all columns of the `drinks` DataFrame, grouping by continent.

# %%
# A:
drinks.groupby('continent').sum()
# Out:
#            beer  spirit  wine  liters
# continent
# AF         3258     866   862   159.4
# AS         1630    2677   399    95.5
# EU         8720    5965  6400   387.8
# OC         1435     935   570    54.1
# SA         2101    1377   749    75.7

# %% [markdown]
# **Q.4** **Note:** If you don't specify a column for the aggregation function, it will be applied to all numeric columns.

# %% [markdown]
# <a id='exercise-4'></a>
#
# ## Exercise #4
#
# ---
#
# **Using the `users` DataFrame**:
# 1. Count the number of distinct occupations in `users`.
# 2. Calculate the mean age by occupation.
# 3. Calculate the minimum and maximum age by occupation.
# 4. Calculate the mean age by cross-sections of `occupation` and `gender`.
#
# > **Tip**: Multiple columns can be passed to the `.groupby()` function for more granular cross-sections.

# %%
users = pd.read_table('../../../../resource-datasets/users/users.txt', sep= '|')

# %%
users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
# A:
len(users.occupation.unique())
# Out:
# 21

# %%
users.groupby('occupation').age.mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
users.groupby('occupation').age.agg(['min', 'max'])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %%
users.groupby(['occupation', 'gender']).age.mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
#                M         34.028986
# programmer     F         32.166667
#                M         33.216667
# retired        F         70.000000
#                M         62.538462
# salesman       F         27.000000
#                M         38.555556
# scientist      F         28.333333
#                M         36.321429
# student        F         20.750000
#                M         22.669118
# technician     F         38.000000
#                M         32.961538
# writer         F         37.631579
#                M         35.346154
# Name: age, dtype: float64

# %% [markdown]
# <a id='indexing'></a>
# ## Indexing
#
# ---
# <a id='loc'></a>
# ### Location Indexing With `.loc()`
#
# **Q.1** Select all rows and the `city` column from the UFO data set using `.loc()`.

# %%
ufo.loc[:, 'City']
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
# 5                 Valley City
# 6                 Crater Lake
# 7                        Alma
# 8                     Eklutna
# 9                     Hubbard
# 10                    Fontana
# 11                   Waterloo
# 12                     Belton
# 13                     Keokuk
# 14                  Ludington
# 15                Forest Home
# 16                Los Angeles
# 17                  Hapeville
# 18                     Oneida
# 19                 Bering Sea
# 20                   Nebraska
# 21                        NaN
# 22                        NaN
# 23                  Owensboro
# 24                 Wilderness
# 25                  San Diego
# 26                 Wilderness
# 27                     Clovis
# 28                 Los Alamos
# 29               Ft. Duschene
#                  ...
# 80513              Manahawkin
# 80514             New Bedford
# 80515              Woodbridge
# 80516                Glendale
# 80517                 Laconia
# 80518               Langhorne
# 80519              Glen Ellyn
# 80520              Waynesburg
# 80521        Canal Winchester
# 80522                Lawrence
# 80523           Ellicott City
# 80524                 Olympia
# 80525               Iowa City
# 80526              Marshfield
# 80527                 Seattle
# 80528          North Royalton
# 80529               Deer Park
# 80530           Glen St. Mary
# 80531                Abingdon
# 80532                Lawrence
# 80533               Melbourne
# 80534                Burleson
# 80535           Elizabethtown
# 80536                 Wyoming
# 80537                  Neligh
# 80538                  Neligh
# 80539            Uhrichsville
# 80540                  Tucson
# 80541             Orland park
# 80542                Loughman
# Name: City, Length: 80543, dtype: object

# %% [markdown]
# **Q.2** Select all rows and columns in `city` and `state`.

# %%
# A:
ufo.loc[:, ['City', 'State']]
# Out:
#                        City State
# 0                    Ithaca    NY
# 1               Willingboro    NJ
# 2                   Holyoke    CO
# 3                   Abilene    KS
# 4      New York Worlds Fair    NY
# 5               Valley City    ND
# 6               Crater Lake    CA
# 7                      Alma    MI
# 8                   Eklutna    AK
# 9                   Hubbard    OR
# 10                  Fontana    CA
# 11                 Waterloo    AL
# 12                   Belton    SC
# 13                   Keokuk    IA
# 14                Ludington    MI
# 15              Forest Home    CA
# 16              Los Angeles    CA
# 17                Hapeville    GA
# 18                   Oneida    TN
# 19               Bering Sea    AK
# 20                 Nebraska    NE
# 21                      NaN    LA
# 22                      NaN    LA
# 23                Owensboro    KY
# 24               Wilderness    WV
# 25                San Diego    CA
# 26               Wilderness    WV
# 27                   Clovis    NM
# 28               Los Alamos    NM
# 29             Ft. Duschene    UT
# ...                     ...   ...
# 80513            Manahawkin    NJ
# 80514           New Bedford    MA
# 80515            Woodbridge    VA
# 80516              Glendale    CA
# 80517               Laconia    NH
# 80518             Langhorne    PA
# 80519            Glen Ellyn    IL
# 80520            Waynesburg    PA
# 80521      Canal Winchester    OH
# 80522              Lawrence    MA
# 80523         Ellicott City    MD
# 80524               Olympia    WA
# 80525             Iowa City    IA
# 80526            Marshfield    MA
# 80527               Seattle    WA
# 80528        North Royalton    OH
# 80529             Deer Park    WA
# 80530         Glen St. Mary    FL
# 80531              Abingdon    VA
# 80532              Lawrence    MA
# 80533             Melbourne    IA
# 80534              Burleson    TX
# 80535         Elizabethtown    KY
# 80536               Wyoming    PA
# 80537                Neligh    NE
# 80538                Neligh    NE
# 80539          Uhrichsville    OH
# 80540                Tucson    AZ
# 80541           Orland park    IL
# 80542              Loughman    FL
#
# [80543 rows x 2 columns]

# %% [markdown]
# **Q.3** Select all rows and columns from `city` *through* `state`.

# %%
# A:
ufo.loc[:, 'City':'State']
# Out:
#                        City Colors Reported Shape Reported State
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# 13                   Keokuk             NaN           OVAL    IA
# 14                Ludington             NaN           DISK    MI
# 15              Forest Home             NaN         CIRCLE    CA
# 16              Los Angeles             NaN            NaN    CA
# 17                Hapeville             NaN            NaN    GA
# 18                   Oneida             NaN      RECTANGLE    TN
# 19               Bering Sea             RED          OTHER    AK
# 20                 Nebraska             NaN           DISK    NE
# 21                      NaN             NaN            NaN    LA
# 22                      NaN             NaN          LIGHT    LA
# 23                Owensboro             NaN      RECTANGLE    KY
# 24               Wilderness             NaN           DISK    WV
# 25                San Diego             NaN          CIGAR    CA
# 26               Wilderness             NaN           DISK    WV
# 27                   Clovis             NaN           DISK    NM
# 28               Los Alamos             NaN           DISK    NM
# 29             Ft. Duschene             NaN           DISK    UT
# ...                     ...             ...            ...   ...
# 80513            Manahawkin             NaN         CIRCLE    NJ
# 80514           New Bedford             NaN          LIGHT    MA
# 80515            Woodbridge             NaN       TRIANGLE    VA
# 80516              Glendale             NaN       CYLINDER    CA
# 80517               Laconia             NaN          CIGAR    NH
# 80518             Langhorne             NaN          OTHER    PA
# 80519            Glen Ellyn             RED         CIRCLE    IL
# 80520            Waynesburg             NaN          FLASH    PA
# 80521      Canal Winchester             NaN       TRIANGLE    OH
# 80522              Lawrence          ORANGE          LIGHT    MA
# 80523         Ellicott City             NaN          LIGHT    MD
# 80524               Olympia             RED          LIGHT    WA
# 80525             Iowa City            BLUE          LIGHT    IA
# 80526            Marshfield             NaN          LIGHT    MA
# 80527               Seattle             NaN        DIAMOND    WA
# 80528        North Royalton             RED       TRIANGLE    OH
# 80529             Deer Park             NaN          LIGHT    WA
# 80530         Glen St. Mary             NaN           DISK    FL
# 80531              Abingdon             NaN         CIRCLE    VA
# 80532              Lawrence             NaN          LIGHT    MA
# 80533             Melbourne             NaN           OVAL    IA
# 80534              Burleson             NaN          LIGHT    TX
# 80535         Elizabethtown             NaN         CIRCLE    KY
# 80536               Wyoming             RED           DISK    PA
# 80537                Neligh             NaN         CIRCLE    NE
# 80538                Neligh             NaN         CIRCLE    NE
# 80539          Uhrichsville             NaN          LIGHT    OH
# 80540                Tucson        RED BLUE            NaN    AZ
# 80541           Orland park             RED          LIGHT    IL
# 80542              Loughman             NaN          LIGHT    FL
#
# [80543 rows x 4 columns]

# %% [markdown]
# **Q.4** Select:
# - All columns at row 0.
# - All columns at rows 0:2.
# - Columns `city` through `state` at rows 0:2.

# %%
# A:
ufo.loc[0, :]                   
ufo.loc[0:2, :]               
ufo.loc[0:2, 'City':'State']
# Out:
#           City Colors Reported Shape Reported State
# 0       Ithaca             NaN       TRIANGLE    NY
# 1  Willingboro             NaN          OTHER    NJ
# 2      Holyoke             NaN           OVAL    CO

# %% [markdown]
# <a id='iloc'></a>
# ### Position indexing with `.iloc`
#
# **Q.1** Select all rows and columns in position 0 and 3.

# %%
# A:
ufo.iloc[:, [0, 3]]
# Out:
#                        City State
# 0                    Ithaca    NY
# 1               Willingboro    NJ
# 2                   Holyoke    CO
# 3                   Abilene    KS
# 4      New York Worlds Fair    NY
# 5               Valley City    ND
# 6               Crater Lake    CA
# 7                      Alma    MI
# 8                   Eklutna    AK
# 9                   Hubbard    OR
# 10                  Fontana    CA
# 11                 Waterloo    AL
# 12                   Belton    SC
# 13                   Keokuk    IA
# 14                Ludington    MI
# 15              Forest Home    CA
# 16              Los Angeles    CA
# 17                Hapeville    GA
# 18                   Oneida    TN
# 19               Bering Sea    AK
# 20                 Nebraska    NE
# 21                      NaN    LA
# 22                      NaN    LA
# 23                Owensboro    KY
# 24               Wilderness    WV
# 25                San Diego    CA
# 26               Wilderness    WV
# 27                   Clovis    NM
# 28               Los Alamos    NM
# 29             Ft. Duschene    UT
# ...                     ...   ...
# 80513            Manahawkin    NJ
# 80514           New Bedford    MA
# 80515            Woodbridge    VA
# 80516              Glendale    CA
# 80517               Laconia    NH
# 80518             Langhorne    PA
# 80519            Glen Ellyn    IL
# 80520            Waynesburg    PA
# 80521      Canal Winchester    OH
# 80522              Lawrence    MA
# 80523         Ellicott City    MD
# 80524               Olympia    WA
# 80525             Iowa City    IA
# 80526            Marshfield    MA
# 80527               Seattle    WA
# 80528        North Royalton    OH
# 80529             Deer Park    WA
# 80530         Glen St. Mary    FL
# 80531              Abingdon    VA
# 80532              Lawrence    MA
# 80533             Melbourne    IA
# 80534              Burleson    TX
# 80535         Elizabethtown    KY
# 80536               Wyoming    PA
# 80537                Neligh    NE
# 80538                Neligh    NE
# 80539          Uhrichsville    OH
# 80540                Tucson    AZ
# 80541           Orland park    IL
# 80542              Loughman    FL
#
# [80543 rows x 2 columns]

# %% [markdown]
# **Q.2** Select all rows and columns in positions 0 through 4.

# %%
# A:
ufo.iloc[:, 0:4]
# Out:
#                        City Colors Reported Shape Reported State
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# 13                   Keokuk             NaN           OVAL    IA
# 14                Ludington             NaN           DISK    MI
# 15              Forest Home             NaN         CIRCLE    CA
# 16              Los Angeles             NaN            NaN    CA
# 17                Hapeville             NaN            NaN    GA
# 18                   Oneida             NaN      RECTANGLE    TN
# 19               Bering Sea             RED          OTHER    AK
# 20                 Nebraska             NaN           DISK    NE
# 21                      NaN             NaN            NaN    LA
# 22                      NaN             NaN          LIGHT    LA
# 23                Owensboro             NaN      RECTANGLE    KY
# 24               Wilderness             NaN           DISK    WV
# 25                San Diego             NaN          CIGAR    CA
# 26               Wilderness             NaN           DISK    WV
# 27                   Clovis             NaN           DISK    NM
# 28               Los Alamos             NaN           DISK    NM
# 29             Ft. Duschene             NaN           DISK    UT
# ...                     ...             ...            ...   ...
# 80513            Manahawkin             NaN         CIRCLE    NJ
# 80514           New Bedford             NaN          LIGHT    MA
# 80515            Woodbridge             NaN       TRIANGLE    VA
# 80516              Glendale             NaN       CYLINDER    CA
# 80517               Laconia             NaN          CIGAR    NH
# 80518             Langhorne             NaN          OTHER    PA
# 80519            Glen Ellyn             RED         CIRCLE    IL
# 80520            Waynesburg             NaN          FLASH    PA
# 80521      Canal Winchester             NaN       TRIANGLE    OH
# 80522              Lawrence          ORANGE          LIGHT    MA
# 80523         Ellicott City             NaN          LIGHT    MD
# 80524               Olympia             RED          LIGHT    WA
# 80525             Iowa City            BLUE          LIGHT    IA
# 80526            Marshfield             NaN          LIGHT    MA
# 80527               Seattle             NaN        DIAMOND    WA
# 80528        North Royalton             RED       TRIANGLE    OH
# 80529             Deer Park             NaN          LIGHT    WA
# 80530         Glen St. Mary             NaN           DISK    FL
# 80531              Abingdon             NaN         CIRCLE    VA
# 80532              Lawrence             NaN          LIGHT    MA
# 80533             Melbourne             NaN           OVAL    IA
# 80534              Burleson             NaN          LIGHT    TX
# 80535         Elizabethtown             NaN         CIRCLE    KY
# 80536               Wyoming             RED           DISK    PA
# 80537                Neligh             NaN         CIRCLE    NE
# 80538                Neligh             NaN         CIRCLE    NE
# 80539          Uhrichsville             NaN          LIGHT    OH
# 80540                Tucson        RED BLUE            NaN    AZ
# 80541           Orland park             RED          LIGHT    IL
# 80542              Loughman             NaN          LIGHT    FL
#
# [80543 rows x 4 columns]

# %% [markdown]
# **Q.3** Select rows in positions 0:3, along with all columns.

# %%
# A:
ufo.iloc[0:3, :]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %% [markdown]
# <a id='frequent'></a>
# ## Frequently Used Features
#
# ---
# <a id='map-dict'></a>
# ### Using Map Functions With Replacement Dictionaries

# %%
# A:
df = pd.DataFrame({'one': {'A': 10, 'B': 20, 'C': 30, 'D': 40, 'E': 50}})
map_dict = {'A': 'every', 'B': 'good', 'C': 'boy', 'D': 'does', 'E': 'fine'}

df['one'] = df.index.to_series().map(map_dict)

df
# Out:
#      one
# A  every
# B   good
# C    boy
# D   does
# E   fine

# %% [markdown]
# <a id='factorize'></a>
# ### Encoding Strings as Integers With `.factorize()`

# %%
# A:
labels , unique = pd.factorize(['b', 'b', 'c'])
labels
# Out:
# array([0, 0, 1])

# %% [markdown]
# <a id='unique'></a>
# ### Determining Unique Values

# %%
# A:
unique
# Out:
# array(['b', 'c'], dtype=object)

# %% [markdown]
# <a id='replace'></a>
# ### Replacing Values With `.replace()`

# %%
# A:
'Yasmin'.replace('Y',"J")
# Out:
# 'Jasmin'

# %% [markdown]
# <a id='series-str'></a>
# ### Series String Methods With `.str`

# %%
# A:
s_str = pd.Series(['A', 'B', 'C'])

# %%
s_str.str.lower()
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
s_str.str.upper()
# Out:
# 0    A
# 1    B
# 2    C
# dtype: object

# %%
s_str.str.len()
# Out:
# 0    1
# 1    1
# 2    1
# dtype: int64

# %% [markdown]
# <a id='datetime'></a>
# ### Datetime Conversion and Arithmetic

# %%
# A:
import datetime
myBD = '17/1/1994'
d = datetime.datetime.strptime(myBD, '%d/%m/%Y') + datetime.timedelta(days=0)
print(d.strftime('%d/%m/%Y'))
# Out:
# 17/01/1994

# %% [markdown]
# <a id='set-reset-index'></a>
# ### Setting and Resetting the Index

# %%
# A:
ufo.reset_index()
# Out:
#        index                  City Colors Reported Shape Reported State  \
# 0          0                Ithaca             NaN       TRIANGLE    NY
# 1          1           Willingboro             NaN          OTHER    NJ
# 2          2               Holyoke             NaN           OVAL    CO
# 3          3               Abilene             NaN           DISK    KS
# 4          4  New York Worlds Fair             NaN          LIGHT    NY
# 5          5           Valley City             NaN           DISK    ND
# 6          6           Crater Lake             NaN         CIRCLE    CA
# 7          7                  Alma             NaN           DISK    MI
# 8          8               Eklutna             NaN          CIGAR    AK
# 9          9               Hubbard             NaN       CYLINDER    OR
# 10        10               Fontana             NaN          LIGHT    CA
# 11        11              Waterloo             NaN       FIREBALL    AL
# 12        12                Belton             RED         SPHERE    SC
# 13        13                Keokuk             NaN           OVAL    IA
# 14        14             Ludington             NaN           DISK    MI
# 15        15           Forest Home             NaN         CIRCLE    CA
# 16        16           Los Angeles             NaN            NaN    CA
# 17        17             Hapeville             NaN            NaN    GA
# 18        18                Oneida             NaN      RECTANGLE    TN
# 19        19            Bering Sea             RED          OTHER    AK
# 20        20              Nebraska             NaN           DISK    NE
# 21        21                   NaN             NaN            NaN    LA
# 22        22                   NaN             NaN          LIGHT    LA
# 23        23             Owensboro             NaN      RECTANGLE    KY
# 24        24            Wilderness             NaN           DISK    WV
# 25        25             San Diego             NaN          CIGAR    CA
# 26        26            Wilderness             NaN           DISK    WV
# 27        27                Clovis             NaN           DISK    NM
# 28        28            Los Alamos             NaN           DISK    NM
# 29        29          Ft. Duschene             NaN           DISK    UT
# ...      ...                   ...             ...            ...   ...
# 80513  80513            Manahawkin             NaN         CIRCLE    NJ
# 80514  80514           New Bedford             NaN          LIGHT    MA
# 80515  80515            Woodbridge             NaN       TRIANGLE    VA
# 80516  80516              Glendale             NaN       CYLINDER    CA
# 80517  80517               Laconia             NaN          CIGAR    NH
# 80518  80518             Langhorne             NaN          OTHER    PA
# 80519  80519            Glen Ellyn             RED         CIRCLE    IL
# 80520  80520            Waynesburg             NaN          FLASH    PA
# 80521  80521      Canal Winchester             NaN       TRIANGLE    OH
# 80522  80522              Lawrence          ORANGE          LIGHT    MA
# 80523  80523         Ellicott City             NaN          LIGHT    MD
# 80524  80524               Olympia             RED          LIGHT    WA
# 80525  80525             Iowa City            BLUE          LIGHT    IA
# 80526  80526            Marshfield             NaN          LIGHT    MA
# 80527  80527               Seattle             NaN        DIAMOND    WA
# 80528  80528        North Royalton             RED       TRIANGLE    OH
# 80529  80529             Deer Park             NaN          LIGHT    WA
# 80530  80530         Glen St. Mary             NaN           DISK    FL
# 80531  80531              Abingdon             NaN         CIRCLE    VA
# 80532  80532              Lawrence             NaN          LIGHT    MA
# 80533  80533             Melbourne             NaN           OVAL    IA
# 80534  80534              Burleson             NaN          LIGHT    TX
# 80535  80535         Elizabethtown             NaN         CIRCLE    KY
# 80536  80536               Wyoming             RED           DISK    PA
# 80537  80537                Neligh             NaN         CIRCLE    NE
# 80538  80538                Neligh             NaN         CIRCLE    NE
# 80539  80539          Uhrichsville             NaN          LIGHT    OH
# 80540  80540                Tucson        RED BLUE            NaN    AZ
# 80541  80541           Orland park             RED          LIGHT    IL
# 80542  80542              Loughman             NaN          LIGHT    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# 5       9/15/1934 15:30
# 6        6/15/1935 0:00
# 7        7/15/1936 0:00
# 8      10/15/1936 17:00
# 9        6/15/1937 0:00
# 10      8/15/1937 21:00
# 11       6/1/1939 20:00
# 12      6/30/1939 20:00
# 13        7/7/1939 2:00
# 14       6/1/1941 13:00
# 15       7/2/1941 11:30
# 16       2/25/1942 0:00
# 17       6/1/1942 22:30
# 18       7/15/1942 1:00
# 19      4/30/1943 23:00
# 20       6/1/1943 15:00
# 21       8/15/1943 0:00
# 22       8/15/1943 0:00
# 23     10/15/1943 11:00
# 24       1/1/1944 10:00
# 25       1/1/1944 12:00
# 26       1/1/1944 12:00
# 27       4/2/1944 11:00
# 28       6/1/1944 12:00
# 29      6/30/1944 10:00
# ...                 ...
# 80513     9/4/2014 8:30
# 80514     9/4/2014 9:47
# 80515    9/4/2014 16:30
# 80516    9/4/2014 17:38
# 80517    9/4/2014 19:02
# 80518    9/4/2014 19:30
# 80519    9/4/2014 20:20
# 80520    9/4/2014 20:25
# 80521    9/4/2014 20:30
# 80522    9/4/2014 20:30
# 80523    9/4/2014 20:45
# 80524    9/4/2014 21:10
# 80525    9/4/2014 21:11
# 80526    9/4/2014 21:15
# 80527    9/4/2014 21:15
# 80528    9/4/2014 21:30
# 80529    9/4/2014 22:00
# 80530    9/4/2014 22:00
# 80531    9/4/2014 22:05
# 80532    9/4/2014 22:15
# 80533    9/4/2014 22:15
# 80534    9/4/2014 22:30
# 80535    9/4/2014 22:30
# 80536    9/4/2014 23:00
# 80537    9/4/2014 23:20
# 80538    9/4/2014 23:20
# 80539     9/5/2014 1:14
# 80540     9/5/2014 2:40
# 80541     9/5/2014 3:43
# 80542     9/5/2014 5:30
#
# [80543 rows x 6 columns]

# %%
ufo.set_index('Time')
# Out:
#                                   City Colors Reported Shape Reported State
# Time
# 6/1/1930 22:00                  Ithaca             NaN       TRIANGLE    NY
# 6/30/1930 20:00            Willingboro             NaN          OTHER    NJ
# 2/15/1931 14:00                Holyoke             NaN           OVAL    CO
# 6/1/1931 13:00                 Abilene             NaN           DISK    KS
# 4/18/1933 19:00   New York Worlds Fair             NaN          LIGHT    NY
# 9/15/1934 15:30            Valley City             NaN           DISK    ND
# 6/15/1935 0:00             Crater Lake             NaN         CIRCLE    CA
# 7/15/1936 0:00                    Alma             NaN           DISK    MI
# 10/15/1936 17:00               Eklutna             NaN          CIGAR    AK
# 6/15/1937 0:00                 Hubbard             NaN       CYLINDER    OR
# 8/15/1937 21:00                Fontana             NaN          LIGHT    CA
# 6/1/1939 20:00                Waterloo             NaN       FIREBALL    AL
# 6/30/1939 20:00                 Belton             RED         SPHERE    SC
# 7/7/1939 2:00                   Keokuk             NaN           OVAL    IA
# 6/1/1941 13:00               Ludington             NaN           DISK    MI
# 7/2/1941 11:30             Forest Home             NaN         CIRCLE    CA
# 2/25/1942 0:00             Los Angeles             NaN            NaN    CA
# 6/1/1942 22:30               Hapeville             NaN            NaN    GA
# 7/15/1942 1:00                  Oneida             NaN      RECTANGLE    TN
# 4/30/1943 23:00             Bering Sea             RED          OTHER    AK
# 6/1/1943 15:00                Nebraska             NaN           DISK    NE
# 8/15/1943 0:00                     NaN             NaN            NaN    LA
# 8/15/1943 0:00                     NaN             NaN          LIGHT    LA
# 10/15/1943 11:00             Owensboro             NaN      RECTANGLE    KY
# 1/1/1944 10:00              Wilderness             NaN           DISK    WV
# 1/1/1944 12:00               San Diego             NaN          CIGAR    CA
# 1/1/1944 12:00              Wilderness             NaN           DISK    WV
# 4/2/1944 11:00                  Clovis             NaN           DISK    NM
# 6/1/1944 12:00              Los Alamos             NaN           DISK    NM
# 6/30/1944 10:00           Ft. Duschene             NaN           DISK    UT
# ...                                ...             ...            ...   ...
# 9/4/2014 8:30               Manahawkin             NaN         CIRCLE    NJ
# 9/4/2014 9:47              New Bedford             NaN          LIGHT    MA
# 9/4/2014 16:30              Woodbridge             NaN       TRIANGLE    VA
# 9/4/2014 17:38                Glendale             NaN       CYLINDER    CA
# 9/4/2014 19:02                 Laconia             NaN          CIGAR    NH
# 9/4/2014 19:30               Langhorne             NaN          OTHER    PA
# 9/4/2014 20:20              Glen Ellyn             RED         CIRCLE    IL
# 9/4/2014 20:25              Waynesburg             NaN          FLASH    PA
# 9/4/2014 20:30        Canal Winchester             NaN       TRIANGLE    OH
# 9/4/2014 20:30                Lawrence          ORANGE          LIGHT    MA
# 9/4/2014 20:45           Ellicott City             NaN          LIGHT    MD
# 9/4/2014 21:10                 Olympia             RED          LIGHT    WA
# 9/4/2014 21:11               Iowa City            BLUE          LIGHT    IA
# 9/4/2014 21:15              Marshfield             NaN          LIGHT    MA
# 9/4/2014 21:15                 Seattle             NaN        DIAMOND    WA
# 9/4/2014 21:30          North Royalton             RED       TRIANGLE    OH
# 9/4/2014 22:00               Deer Park             NaN          LIGHT    WA
# 9/4/2014 22:00           Glen St. Mary             NaN           DISK    FL
# 9/4/2014 22:05                Abingdon             NaN         CIRCLE    VA
# 9/4/2014 22:15                Lawrence             NaN          LIGHT    MA
# 9/4/2014 22:15               Melbourne             NaN           OVAL    IA
# 9/4/2014 22:30                Burleson             NaN          LIGHT    TX
# 9/4/2014 22:30           Elizabethtown             NaN         CIRCLE    KY
# 9/4/2014 23:00                 Wyoming             RED           DISK    PA
# 9/4/2014 23:20                  Neligh             NaN         CIRCLE    NE
# 9/4/2014 23:20                  Neligh             NaN         CIRCLE    NE
# 9/5/2014 1:14             Uhrichsville             NaN          LIGHT    OH
# 9/5/2014 2:40                   Tucson        RED BLUE            NaN    AZ
# 9/5/2014 3:43              Orland park             RED          LIGHT    IL
# 9/5/2014 5:30                 Loughman             NaN          LIGHT    FL
#
# [80543 rows x 4 columns]

# %% [markdown]
# <a id='sort-by-index'></a>
# ### Sorting by Index

# %%
# A:
ufo.sort_index()
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# 13                   Keokuk             NaN           OVAL    IA
# 14                Ludington             NaN           DISK    MI
# 15              Forest Home             NaN         CIRCLE    CA
# 16              Los Angeles             NaN            NaN    CA
# 17                Hapeville             NaN            NaN    GA
# 18                   Oneida             NaN      RECTANGLE    TN
# 19               Bering Sea             RED          OTHER    AK
# 20                 Nebraska             NaN           DISK    NE
# 21                      NaN             NaN            NaN    LA
# 22                      NaN             NaN          LIGHT    LA
# 23                Owensboro             NaN      RECTANGLE    KY
# 24               Wilderness             NaN           DISK    WV
# 25                San Diego             NaN          CIGAR    CA
# 26               Wilderness             NaN           DISK    WV
# 27                   Clovis             NaN           DISK    NM
# 28               Los Alamos             NaN           DISK    NM
# 29             Ft. Duschene             NaN           DISK    UT
# ...                     ...             ...            ...   ...
# 80513            Manahawkin             NaN         CIRCLE    NJ
# 80514           New Bedford             NaN          LIGHT    MA
# 80515            Woodbridge             NaN       TRIANGLE    VA
# 80516              Glendale             NaN       CYLINDER    CA
# 80517               Laconia             NaN          CIGAR    NH
# 80518             Langhorne             NaN          OTHER    PA
# 80519            Glen Ellyn             RED         CIRCLE    IL
# 80520            Waynesburg             NaN          FLASH    PA
# 80521      Canal Winchester             NaN       TRIANGLE    OH
# 80522              Lawrence          ORANGE          LIGHT    MA
# 80523         Ellicott City             NaN          LIGHT    MD
# 80524               Olympia             RED          LIGHT    WA
# 80525             Iowa City            BLUE          LIGHT    IA
# 80526            Marshfield             NaN          LIGHT    MA
# 80527               Seattle             NaN        DIAMOND    WA
# 80528        North Royalton             RED       TRIANGLE    OH
# 80529             Deer Park             NaN          LIGHT    WA
# 80530         Glen St. Mary             NaN           DISK    FL
# 80531              Abingdon             NaN         CIRCLE    VA
# 80532              Lawrence             NaN          LIGHT    MA
# 80533             Melbourne             NaN           OVAL    IA
# 80534              Burleson             NaN          LIGHT    TX
# 80535         Elizabethtown             NaN         CIRCLE    KY
# 80536               Wyoming             RED           DISK    PA
# 80537                Neligh             NaN         CIRCLE    NE
# 80538                Neligh             NaN         CIRCLE    NE
# 80539          Uhrichsville             NaN          LIGHT    OH
# 80540                Tucson        RED BLUE            NaN    AZ
# 80541           Orland park             RED          LIGHT    IL
# 80542              Loughman             NaN          LIGHT    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# 5       9/15/1934 15:30
# 6        6/15/1935 0:00
# 7        7/15/1936 0:00
# 8      10/15/1936 17:00
# 9        6/15/1937 0:00
# 10      8/15/1937 21:00
# 11       6/1/1939 20:00
# 12      6/30/1939 20:00
# 13        7/7/1939 2:00
# 14       6/1/1941 13:00
# 15       7/2/1941 11:30
# 16       2/25/1942 0:00
# 17       6/1/1942 22:30
# 18       7/15/1942 1:00
# 19      4/30/1943 23:00
# 20       6/1/1943 15:00
# 21       8/15/1943 0:00
# 22       8/15/1943 0:00
# 23     10/15/1943 11:00
# 24       1/1/1944 10:00
# 25       1/1/1944 12:00
# 26       1/1/1944 12:00
# 27       4/2/1944 11:00
# 28       6/1/1944 12:00
# 29      6/30/1944 10:00
# ...                 ...
# 80513     9/4/2014 8:30
# 80514     9/4/2014 9:47
# 80515    9/4/2014 16:30
# 80516    9/4/2014 17:38
# 80517    9/4/2014 19:02
# 80518    9/4/2014 19:30
# 80519    9/4/2014 20:20
# 80520    9/4/2014 20:25
# 80521    9/4/2014 20:30
# 80522    9/4/2014 20:30
# 80523    9/4/2014 20:45
# 80524    9/4/2014 21:10
# 80525    9/4/2014 21:11
# 80526    9/4/2014 21:15
# 80527    9/4/2014 21:15
# 80528    9/4/2014 21:30
# 80529    9/4/2014 22:00
# 80530    9/4/2014 22:00
# 80531    9/4/2014 22:05
# 80532    9/4/2014 22:15
# 80533    9/4/2014 22:15
# 80534    9/4/2014 22:30
# 80535    9/4/2014 22:30
# 80536    9/4/2014 23:00
# 80537    9/4/2014 23:20
# 80538    9/4/2014 23:20
# 80539     9/5/2014 1:14
# 80540     9/5/2014 2:40
# 80541     9/5/2014 3:43
# 80542     9/5/2014 5:30
#
# [80543 rows x 5 columns]

# %% [markdown]
# <a id='change-dtype'></a>
# ### Changing the Data Type of a Column

# %%
# A:
import datetime as dt  
ufo['Time'].dtypes
ufo['Time'] = pd.to_datetime(ufo['Time'])
ufo['Time'].dtypes
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# <a id='dummy'></a>
# ### Creating Dummy-Coded Columns

# %%
# A:
dummy = pd.Series(['a','v','d'])
pd.get_dummies(dummy)
# Out:
#    a  d  v
# 0  1  0  0
# 1  0  0  1
# 2  0  1  0

# %% [markdown]
# <a id='concatenate'></a>
# ### Concatenating DataFrames

# %%
# A:
result = pd.concat([dummy,s_str], keys=['a', 'v', 'd'])
result
# Out:
# a  0    a
#    1    v
#    2    d
# v  0    A
#    1    B
#    2    C
# dtype: object

# %% [markdown]
# <a id='duplicate-rows'></a>
# ### Detecting and Dropping Duplicate Rows

# %%
# A:
result.drop_duplicates()
result
# Out:
# a  0    a
#    1    v
#    2    d
# v  0    A
#    1    B
#    2    C
# dtype: object

# %% [markdown]
# <a id='write-csv'></a>
# ### Writing a DataFrame to a `.csv`
# ```python
# # Write a DataFrame out to a `.csv`.
# drinks.to_csv('drinks_updated.csv')  # Index is used as the first column
# drinks.to_csv('drinks_updated.csv', index=False) # Ignore index
# ```

# %% [markdown]
# <a id='pickle'></a>
# ### Pickling a DataFrame
# ```python
# # Save a DataFrame to disk (a.k.a., "pickle") and read it from disk (a.k.a., "unpickle").
# drinks.to_pickle('drinks_pickle')
# pd.read_pickle('drinks_pickle')
# ```

# %% [markdown]
# <a id='sample'></a>
# ### Randomly Sampling a DataFrame

# %%
# A:
result.sample(frac=0.2)
# Out:
# a  1    v
# dtype: object

# %% [markdown]
# <a id='infrequent'></a>
# ## Infrequently Used Features
#
# ---
#
# <a id='toy-dataframes'></a>
# ### Creating DataFrames From Dictionaries and Lists of Lists

# %%
# A: From Dict
test_dict = [{'one':'A','Two':'B'}]
test_dict_DF = pd.DataFrame(test_dict)
test_dict_DF.head()
# Out:
#   Two one
# 0   B   A

# %%
# A:
test_list = [['one','A'],['Two','B']]
test_list_DF = pd.DataFrame(test_list)
test_list_DF.head()
# Out:
#      0  1
# 0  one  A
# 1  Two  B

# %% [markdown]
# <a id='crosstab'></a>
# ### Performing Cross-Tabulations

# %%
# A:
list1 = ['a','b','c']
list2 = ['d','f','g']
list3 = ['h','e','k']
pd.crosstab(list1, [list2, list3])
# Out:
# col_0              d  f  g
# col_1              h  e  k
# row_0 row_1 row_2
# a     b     c      1  1  1

# %% [markdown]
# <a id='query'></a>
# ### Query-Filtering Syntax

# %%
# A:
ufo.query('State == "NY"')
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 41            New York City             NaN           DISK    NY
# 50                 Syracuse             NaN           DISK    NY
# 74                 Syracuse             NaN          CIGAR    NY
# 87             Saranac Lake             NaN           DISK    NY
# 96            New York City             NaN         CIRCLE    NY
# 119           New York City             NaN           OVAL    NY
# 158         Jackson Heights             NaN           DISK    NY
# 171              Binghamton             NaN           DISK    NY
# 192           New York City             NaN           DISK    NY
# 208           New York City             NaN          OTHER    NY
# 268                    Ovid             NaN           DISK    NY
# 296                 Oakdale             NaN           DISK    NY
# 297          Bridge Hampton             NaN          LIGHT    NY
# 298             Farmingdale             NaN           OVAL    NY
# 303                  Geneva             NaN           DISK    NY
# 313           New York City             NaN          LIGHT    NY
# 345               Rhinebeck             NaN          LIGHT    NY
# 362       Richfield Springs             NaN          CIGAR    NY
# 367           New York City             NaN          LIGHT    NY
# 398               Rhinebeck             NaN        DIAMOND    NY
# 402             Glens Falls             NaN           DISK    NY
# 404              Hicksville             NaN         CIRCLE    NY
# 416           New York City             NaN       TEARDROP    NY
# 419                  Barker             NaN           DISK    NY
# 440             Ticonderoga             NaN           DISK    NY
# 462           New York City             NaN            NaN    NY
# 480           New York City             NaN           OVAL    NY
# 488                 Yonkers             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 80144         New York City             NaN       FIREBALL    NY
# 80148                Colden      RED ORANGE         CIRCLE    NY
# 80155               Wantagh             NaN       FIREBALL    NY
# 80183              Kingston          YELLOW         SPHERE    NY
# 80184             Oceanside             NaN          LIGHT    NY
# 80189         New York City          ORANGE         CIRCLE    NY
# 80197          Watkins Glen             NaN         CIRCLE    NY
# 80201                Auburn             NaN       FIREBALL    NY
# 80220         Morrisonville             RED          LIGHT    NY
# 80259         Central Islip             NaN          LIGHT    NY
# 80265                  Peru             NaN          LIGHT    NY
# 80277             Rochester             NaN       TRIANGLE    NY
# 80294          Westmoreland          ORANGE          LIGHT    NY
# 80314              Red Hook             RED       FIREBALL    NY
# 80335             Riverhead          ORANGE           OVAL    NY
# 80340            Massapequa             NaN          LIGHT    NY
# 80354              Sayville            BLUE       FIREBALL    NY
# 80362               Merrick          ORANGE          LIGHT    NY
# 80367              Lockport             NaN         CIRCLE    NY
# 80369        East Northport             NaN       FIREBALL    NY
# 80371       Clarence Center        RED BLUE            NaN    NY
# 80374              Syracuse             NaN         CIRCLE    NY
# 80383         New York City             NaN         CIRCLE    NY
# 80389             Liverpool             NaN       TRIANGLE    NY
# 80392              Syracuse          ORANGE        DIAMOND    NY
# 80410       North Tonawanda             NaN          OTHER    NY
# 80457              Syracuse          ORANGE         CIRCLE    NY
# 80488             Brentwood             NaN       TRIANGLE    NY
# 80496         New York City             RED          FLASH    NY
# 80505              Clarence          YELLOW       TRIANGLE    NY
#
#                      Time
# 0     1930-06-01 22:00:00
# 4     1933-04-18 19:00:00
# 41    1946-01-08 02:00:00
# 50    1947-02-20 22:15:00
# 74    1947-07-14 10:30:00
# 87    1947-08-12 22:00:00
# 96    1948-08-01 02:00:00
# 119   1950-01-02 00:00:00
# 158   1951-06-30 07:00:00
# 171   1952-02-10 21:00:00
# 192   1952-06-30 13:00:00
# 208   1952-07-15 19:00:00
# 268   1954-06-01 06:00:00
# 296   1954-07-15 21:00:00
# 297   1954-07-15 22:00:00
# 298   1954-08-01 12:00:00
# 303   1954-09-01 13:00:00
# 313   1955-02-15 19:00:00
# 345   1955-10-15 20:00:00
# 362   1956-06-15 18:00:00
# 367   1956-06-15 21:00:00
# 398   1957-05-25 13:00:00
# 402   1957-06-01 20:00:00
# 404   1957-06-06 22:00:00
# 416   1957-06-30 12:00:00
# 419   1957-06-30 20:00:00
# 440   1957-08-14 16:00:00
# 462   1957-10-15 02:00:00
# 480   1958-06-01 21:00:00
# 488   1958-06-15 15:00:00
# ...                   ...
# 80144 2014-08-22 04:00:00
# 80148 2014-08-22 09:50:00
# 80155 2014-08-22 20:45:00
# 80183 2014-08-23 20:30:00
# 80184 2014-08-23 20:30:00
# 80189 2014-08-23 21:10:00
# 80197 2014-08-23 21:30:00
# 80201 2014-08-23 22:00:00
# 80220 2014-08-23 23:30:00
# 80259 2014-08-25 20:30:00
# 80265 2014-08-25 21:15:00
# 80277 2014-08-25 22:15:00
# 80294 2014-08-26 20:30:00
# 80314 2014-08-27 20:15:00
# 80335 2014-08-28 05:00:00
# 80340 2014-08-28 08:45:00
# 80354 2014-08-28 20:30:00
# 80362 2014-08-28 22:03:00
# 80367 2014-08-28 22:30:00
# 80369 2014-08-28 23:30:00
# 80371 2014-08-29 05:00:00
# 80374 2014-08-29 12:30:00
# 80383 2014-08-29 21:40:00
# 80389 2014-08-29 23:00:00
# 80392 2014-08-29 23:50:00
# 80410 2014-08-30 21:40:00
# 80457 2014-09-01 16:05:00
# 80488 2014-09-03 03:57:00
# 80496 2014-09-03 19:00:00
# 80505 2014-09-03 21:30:00
#
# [3677 rows x 5 columns]

# %% [markdown]
# <a id='memory-usage'></a>
# ### Calculating Memory Usage

# %%
# A:
import os
import psutil
process = psutil.Process(os.getpid())
print(process.memory_info().rss)
# Out:
# 43941888

# %% [markdown]
# <a id='category-type'></a>
# ### Converting Column to Category Type

# %%
# A:
ufo['Time'] = ufo['Time'].astype('category')
ufo['Time'].dtypes
# Out:
# CategoricalDtype(categories=['1930-06-01 22:00:00', '1930-06-30 20:00:00',
#                   '1931-02-15 14:00:00', '1931-06-01 13:00:00',
#                   '1933-04-18 19:00:00', '1934-09-15 15:30:00',
#                   '1935-06-15 00:00:00', '1936-07-15 00:00:00',
#                   '1936-10-15 17:00:00', '1937-06-15 00:00:00',
#                   ...
#                   '2014-09-04 22:00:00', '2014-09-04 22:05:00',
#                   '2014-09-04 22:15:00', '2014-09-04 22:30:00',
#                   '2014-09-04 23:00:00', '2014-09-04 23:20:00',
#                   '2014-09-05 01:14:00', '2014-09-05 02:40:00',
#                   '2014-09-05 03:43:00', '2014-09-05 05:30:00'],
#                  ordered=False)

# %% [markdown]
# <a id='assign'></a>
# ### Creating Columns With `.assign()`

# %%
# A:
df = pd.DataFrame({'A':['a','b'], 'B': ['c','d']})
df.head()
# Out:
#    A  B
# 0  a  c
# 1  b  d

# %%
df.assign(D=['e','f'])
# Out:
#    A  B  D
# 0  a  c  e
# 1  b  d  f

# %% [markdown]
# <a id='limit-rows-read'></a>
# ### Limiting the Number of Rows to Load in a File Read

# %%
# A:
users = pd.read_table('../../../../resource-datasets/users/users.txt', sep= '|' , nrows = 3)
users.head()
# Out:
#    user_id  age gender  occupation  zip_code
# 0        1   24      M  technician     85711
# 1        2   53      F       other     94043
# 2        3   23      M      writer     32067

# %% [markdown]
# <a id='manual-print'></a>
# ### Manually Setting the Number of Rows and Columns to Print

# %%
# A:
pd.set_option("display.max_rows",999)
pd.set_option("display.max_columns",999)
